# %% [markdown]
# # 01 — Explore & Validate
# This notebook explains the time-based split and how RMSE is computed.

# %% [markdown]
# ## Goals
# - Understand schema & splits
# - Implement B0 baseline
# - Measure offline RMSE

# %%
import numpy as np, pandas as pd
print('ready')
